# %%
import requests
from requests.auth import HTTPDigestAuth
import json

# %%
urlAutenticacion = "https://checaliadoscomerciales.chec.com.co/api/login/authenticate"
credenciales = {"Username": "apiumaliados", "Password": "Chec2020dic11_A"}

# %%
solicitudAutenticacion = requests.post(urlAutenticacion, json = credenciales)

# %%
solicitudAutenticacion.content
# Out:
# b'"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6ImFwaXVtYWxpYWRvcyIsIm5iZiI6MTYxNDEzMTQzNSwiZXhwIjoxNjE0MTMzMjM1LCJpYXQiOjE2MTQxMzE0MzUsImlzcyI6Imh0dHA6Ly9sb2NhbGhvc3Q6NDkyMjAiLCJhdWQiOiJodHRwOi8vbG9jYWxob3N0OjQ5MjIwIn0.Xl0Zdu_1YAdHF2fRHDeEoGUwkya1DYsdOIvs2ts1kaE"'

# %%
solicitudAutenticacion
# Out:
# <Response [200]>

# %%
solicitudAutenticacion.elapsed
# Out:
# datetime.timedelta(0, 5, 993440)

# %%
solicitudAutenticacion.status_code
# Out:
# 200

# %%
solicitudAutenticacion.raw

# %%
solicitudAutenticacion.headers
# Out:
# {'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Content-Type': 'application/json; charset=utf-8', 'Expires': '-1', 'Server': 'Microsoft-IIS/7.5', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Date': 'Wed, 24 Feb 2021 01:50:35 GMT', 'Content-Length': '274'}

# %%
solicitudAutenticacion.next

# %%
dir(solicitudAutenticacion)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
solicitudAutenticacion
# Out:
# False

# %%
[i for i in solicitudAutenticacion.iter_content()]
# Out:
# [b'"',
#  b'e',
#  b'y',
#  b'J',
#  b'h',
#  b'b',
#  b'G',
#  b'c',
#  b'i',
#  b'O',
#  b'i',
#  b'J',
#  b'I',
#  b'U',
#  b'z',
#  b'I',
#  b'1',
#  b'N',
#  b'i',
#  b'I',
#  b's',
#  b'I',
#  b'n',
#  b'R',
#  b'5',
#  b'c',
#  b'C',
#  b'I',
#  b'6',
#  b'I',
#  b'k',
#  b'p',
#  b'X',
#  b'V',
#  b'C',
#  b'J',
#  b'9',
#  b'.',
#  b'e',
#  b'y',
#  b'J',
#  b'1',
#  b'b',
#  b'm',
#  b'l',
#  b'x',
#  b'd',
#  b'W',
#  b'V',
#  b'f',
#  b'b',
#  b'm',
#  b'F',
#  b't',
#  b'Z',
#  b'S',
#  b'I',
#  b'6',
#  b'I',
#  b'm',
#  b'F',
#  b'w',
#  b'a',
#  b'X',
#  b'V',
#  b't',
#  b'Y',
#  b'W',
#  b'x',
#  b'p',
#  b'Y',
#  b'W',
#  b'R',
#  b'v',
#  b'c',
#  b'y',
#  b'I',
#  b's',
#  b'I',
#  b'm',
#  b'5',
#  b'i',
#  b'Z',
#  b'i',
#  b'I',
#  b'6',
#  b'M',
#  b'T',
#  b'Y',
#  b'x',
#  b'N',
#  b'D',
#  b'E',
#  b'z',
#  b'M',
#  b'T',
#  b'Q',
#  b'z',
#  b'N',
#  b'S',
#  b'w',
#  b'i',
#  b'Z',
#  b'X',
#  b'h',
#  b'w',
#  b'I',
#  b'j',
#  b'o',
#  b'x',
#  b'N',
# ...

# %%
forms:
  info_somos_form:
    articulo:
      - type: from_entity
        entity: articulo
    ubicacion:
      - type: from_entity
        entity: ubicacion

# %%
  - name: "RulePolicy"
    # https://rasa.com/docs/rasa/fallback-handoff#handling-low-action-confidence
    # To handle cases when the machine learning policies can't predict the next action with high confidence, you can configure the Rule Policy to predict a default action if no Policy has a next action
    # prediction with confidence above a configurable threshold.
    # Confidence threshold for the `core_fallback_action_name` to apply.
    # The action will apply if no other action was predicted with
    # a confidence >= core_fallback_threshold
    core_fallback_threshold: 0.3 # confidence threshold
    core_fallback_action_name: action_default_fallback # action that is run in case low of action confidence
    enable_fallback_prediction: true
    restrict_rules: true
    check_for_contradictions: true

# %%
credenciales = {"Username": "apiumaliados", "Password": "Chec2020dic11_A"}
urlAutenticacion = "https://checaliadoscomerciales.chec.com.co/api/login/authenticate"
solicitudAutenticacion = requests.post(urlAutenticacion, json = credenciales)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/anaconda3/envs/asistenteChec/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/anaconda3/envs/asistenteChec/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/anaconda3/envs/asistenteChec/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# ...

# %%
# !conda list
# Out:
# # packages in environment at /home/testchec/anaconda3/envs/asistenteChec:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                    pypi_0    pypi
# aiofiles                  0.5.0                    pypi_0    pypi
# aiohttp                   3.6.2                    pypi_0    pypi
# apscheduler               3.6.3                    pypi_0    pypi
# argon2-cffi               20.1.0                   pypi_0    pypi
# astor                     0.8.1                    pypi_0    pypi
# async-generator           1.10                     pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     19.3.0                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# bleach                    3.2.1                    pypi_0    pypi
# ...

# %%
# !pwd
# Out:
# /home/testchec/asistente

# %%
# !conda list
# Out:
# # packages in environment at /home/testchec/anaconda3/envs/asistenteChec:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                    pypi_0    pypi
# aiofiles                  0.5.0                    pypi_0    pypi
# aiohttp                   3.6.2                    pypi_0    pypi
# apscheduler               3.6.3                    pypi_0    pypi
# argon2-cffi               20.1.0                   pypi_0    pypi
# astor                     0.8.1                    pypi_0    pypi
# async-generator           1.10                     pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     19.3.0                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# bleach                    3.2.1                    pypi_0    pypi
# ...
